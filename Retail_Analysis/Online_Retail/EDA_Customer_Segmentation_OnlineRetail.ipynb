# %% [markdown]
# ### EDA Content:
# - What are the top 10 Product categories based on sales?
# - Who are the most valuable customers?
# - In each country , which product is sold the most?
# - Sales were highest on which day?
# - Sales trend in the countries over time
# - Top 5 Most common countries
# - Top 5 Least common countries
# - Total unit price sold by year
# - Total quantity sold by invoiceno
# - Total quantity sold by Stockcode
# - StockCode Feature Analysis
# - Description Feature Analysis
# - Custumers Analysis
# - Transaction Analysis based on time
#
# RFM Analysis - Time series analysis for marketing RFM (recency, frequency, monetary) analysis is a marketing technique used to determine quantitatively which customers are the best ones by examining how recently a customer has purchased (recency), how often they purchase (frequency), and how much the customer spends (monetary).
#
# Which country has more valuable customers ?
#
# Who are the most valuable customers?
#
# Who is the most frequent and least frequent customer?
#
# Which customers spent the most and least?
#
# We will be computing who are most valuable customers are by calculating their overall RFM scores
#
# ### Customer Segment analysis, KMeans Clustering and Hierarchical Clustering
# -Segment customers into multiple groups according to their RFM Scores
# -Segment customers using Recency, Frequeny and Monetary analysis scores via KMeans clustering
# -Segment customer with RFM dataset via Hierarchical clustering using dendrograms

# %%
#Importing necessary libraries
import pandas as pd
import numpy as np
import os 
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno
sns.set(rc={'figure.figsize':(7,5)})

# %%
# Path to Retail Data-set (online_retail_II.xlsx)
DATA_PATH = "/content/online_retail_II.xlsx"
retaildata = pd.read_excel(DATA_PATH)

# %%
retaildata.head()
# Out:
#   Invoice StockCode  ... Customer ID         Country
# 0  489434     85048  ...     13085.0  United Kingdom
# 1  489434    79323P  ...     13085.0  United Kingdom
# 2  489434    79323W  ...     13085.0  United Kingdom
# 3  489434     22041  ...     13085.0  United Kingdom
# 4  489434     21232  ...     13085.0  United Kingdom
#
# [5 rows x 8 columns]

# %%
retaildata.describe()
# Out:
#             Quantity          Price    Customer ID
# count  525461.000000  525461.000000  417534.000000
# mean       10.337667       4.688834   15360.645478
# std       107.424110     146.126914    1680.811316
# min     -9600.000000  -53594.360000   12346.000000
# 25%         1.000000       1.250000   13983.000000
# 50%         3.000000       2.100000   15311.000000
# 75%        10.000000       4.210000   16799.000000
# max     19152.000000   25111.090000   18287.000000

# %%
retaildata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525461 entries, 0 to 525460
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      525461 non-null  object
#  1   StockCode    525461 non-null  object
#  2   Description  522533 non-null  object
#  3   Quantity     525461 non-null  int64
#  4   InvoiceDate  525461 non-null  datetime64[ns]
#  5   Price        525461 non-null  float64
#  6   Customer ID  417534 non-null  float64
#  7   Country      525461 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 32.1+ MB

# %%
print('Shape of dataset: ', retaildata.shape)
# Out:
# Shape of dataset:  (525461, 8)

# %%
def extract_column_types(df):
    num_cols = [i for i in df.columns if df[i].dtype in ['int64','float64']]
    cat_cols = [i for i in df.columns if df[i].dtype in ['object']]
    date_cols = [i for i in df.columns if df[i].dtype in ['datetime64[ns]']]
    bool_cols = [i for i in df.columns if df[i].dtype in ['bool']]
    return(num_cols,cat_cols,date_cols,bool_cols)

# %%
num_cols,cat_cols,date_cols,bool_cols = extract_column_types(retaildata)
print ("Numeric Columns:", len(num_cols))
print ("Categorical Columns:", len(cat_cols))
print ("Date Columns:",len(date_cols))
print ("Boolean Columns:",len(bool_cols))
# Out:
# Numeric Columns: 3
# Categorical Columns: 4
# Date Columns: 1
# Boolean Columns: 0

# %%
#Filtering the dataset by choosing positive values of Quantity and retaildata
filtered_retaildata = retaildata[(retaildata.Quantity>0) & (retaildata.Price > 0)].copy()

# %%
print('Shape of filtered dataset: ', filtered_retaildata.shape)
# Out:
# Shape of filtered dataset:  (511566, 8)

# %% [markdown]
# #### What are the top 10 Product categories based on sales?

# %%
prod_bought = filtered_retaildata.groupby('Description').agg({'Quantity':np.sum}).reset_index()

# %%
x = prod_bought.sort_values('Quantity' , ascending=False).Description.head(10)
y = prod_bought.sort_values('Quantity' , ascending=False).Quantity.head(10)

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.barh(x,y)
ax.invert_yaxis()
ax.set_title('Top 10 Product categories based on sales')
plt.show()

# %% [markdown]
# #### Product with highest sales in each country?

# %%
country_count = retaildata.groupby(['Country','Description']).agg({'Quantity':np.sum}).reset_index()

# %%
country_count.columns = ['Country','Description','Count']

# %%
filtered_retaildata['Revenue'] = filtered_retaildata.Price * filtered_retaildata.Quantity

# %%
for i in country_count.Country.unique():
    temp = country_count[country_count.Country == i]
    prod = temp.Description[temp.Count == np.max(temp.Count)].values[0]
    count = np.max(temp.Count)
    revenue = np.round((np.sum(filtered_retaildata.Revenue[(filtered_retaildata.Description == prod) & (filtered_retaildata.Country == i)])),2)
    print ("Product with highest sales in {} is {} \n The sales count (in units) is : {} and revenue generated is {} ".format(i,prod,count,revenue))
    print('-----------------------------------------------------')
# Out:
# Product with highest sales in Australia is 60 CAKE CASES DOLLY GIRL DESIGN
#  The sales count (in units) is : 504 and revenue generated is 214.8
# -----------------------------------------------------
# Product with highest sales in Austria is MINI HIGHLIGHTER PENS
#  The sales count (in units) is : 120 and revenue generated is 14.4
# -----------------------------------------------------
# Product with highest sales in Bahrain is WHITE TALL PORCELAIN T-LIGHT HOLDER
#  The sales count (in units) is : 102 and revenue generated is 202.5
# -----------------------------------------------------
# Product with highest sales in Belgium is PACK OF 60 MUSHROOM CAKE CASES
#  The sales count (in units) is : 264 and revenue generated is 145.2
# -----------------------------------------------------
# Product with highest sales in Bermuda is BOYS ALPHABET IRON ON PATCHES
#  The sales count (in units) is : 1152 and revenue generated is 241.92
# -----------------------------------------------------
# Product with highest sales in Brazil is DRAGONS BLOOD INCENSE
#  The sales count (in units) is : 25 and revenue generated is 5.25
# -----------------------------------------------------
# Product with highest sales in Canada is JAZZ HEARTS ADDRESS BOOK
#  The sales count (in units) is : 24 and revenue generated is 10.08
# -----------------------------------------------------
# Product with highest sales in Channel Islands is JUMBO BAG PINK WITH WHITE SPOTS
#  The sales count (in units) is : 330 and revenue generated is 553.5
# -----------------------------------------------------
# Product with highest sales in Cyprus is BLUE SCANDINAVIAN PAISLEY WRAP
#  The sales count (in units) is : 200 and revenue generated is 68.0
# -----------------------------------------------------
# Product with highest sales in Denmark is BLACK AND WHITE PAISLEY FLOWER MUG
#  The sales count (in units) is : 25164 and revenue generated is 2516.4
# -----------------------------------------------------
# Product with highest sales in EIRE is PACK OF 72 RETRO SPOT CAKE CASES
#  The sales count (in units) is : 4080 and revenue generated is 1838.4
# -----------------------------------------------------
# Product with highest sales in Finland is PINK 3 PIECE MINI DOTS CUTLERY SET
#  The sales count (in units) is : 162 and revenue generated is 555.66
# -----------------------------------------------------
# Product with highest sales in France is RED SPOTTY PUDDING BOWL
#  The sales count (in units) is : 3690 and revenue generated is 562.44
# -----------------------------------------------------
# Product with highest sales in Germany is WOODLAND CHARLOTTE BAG
#  The sales count (in units) is : 1585 and revenue generated is 1312.5
# -----------------------------------------------------
# Product with highest sales in Greece is WHITE HANGING HEART T-LIGHT HOLDER
#  The sales count (in units) is : 160 and revenue generated is 408.0
# -----------------------------------------------------
# Product with highest sales in Hong Kong is PLASTERS IN TIN SPACEBOY
#  The sales count (in units) is : 108 and revenue generated is 159.0
# -----------------------------------------------------
# Product with highest sales in Iceland is MINI PAINT SET VINTAGE
#  The sales count (in units) is : 36 and revenue generated is 23.4
# -----------------------------------------------------
# Product with highest sales in Israel is LOVEBIRD HANGING DECORATION WHITE
#  The sales count (in units) is : 36 and revenue generated is 30.6
# -----------------------------------------------------
# Product with highest sales in Italy is INFLATABLE POLITICAL GLOBE
#  The sales count (in units) is : 360 and revenue generated is 267.0
# -----------------------------------------------------
# Product with highest sales in Japan is ROUND SNACK BOXES SET OF 4 FRUITS
#  The sales count (in units) is : 1488 and revenue generated is 3820.95
# -----------------------------------------------------
# Product with highest sales in Korea is CACTI T-LIGHT CANDLES
#  The sales count (in units) is : 48 and revenue generated is 20.16
# -----------------------------------------------------
# Product with highest sales in Lebanon is PLASTERS IN TIN SKULLS
#  The sales count (in units) is : 12 and revenue generated is 19.8
# -----------------------------------------------------
# Product with highest sales in Lithuania is GOLD MUG BONE CHINA TREE OF LIFE
#  The sales count (in units) is : 72 and revenue generated is 118.8
# -----------------------------------------------------
# Product with highest sales in Malta is VICTORIAN SEWING KIT
#  The sales count (in units) is : 144 and revenue generated is 122.4
# -----------------------------------------------------
# Product with highest sales in Netherlands is FOLKART ZINC HEART CHRISTMAS DEC
#  The sales count (in units) is : 5425 and revenue generated is 3937.33
# -----------------------------------------------------
# Product with highest sales in Nigeria is EMPIRE GIFT WRAP
#  The sales count (in units) is : 25 and revenue generated is 10.5
# -----------------------------------------------------
# Product with highest sales in Norway is PINK HEART SHAPE EGG FRYING PAN
#  The sales count (in units) is : 194 and revenue generated is 262.5
# -----------------------------------------------------
# Product with highest sales in Poland is STRAWBERRY CERAMIC TRINKET BOX
#  The sales count (in units) is : 120 and revenue generated is 150.0
# -----------------------------------------------------
# Product with highest sales in Portugal is LUNCH BAG RED SPOTTY
#  The sales count (in units) is : 200 and revenue generated is 310.0
# -----------------------------------------------------
# Product with highest sales in RSA is PINK  POLKADOT CUP
#  The sales count (in units) is : 96 and revenue generated is 69.12
# -----------------------------------------------------
# Product with highest sales in Singapore is WHITE HANGING HEART T-LIGHT HOLDER
#  The sales count (in units) is : 96 and revenue generated is 244.8
# -----------------------------------------------------
# Product with highest sales in Spain is ASSORTED COLOUR BIRD ORNAMENT
#  The sales count (in units) is : 592 and revenue generated is 923.68
# -----------------------------------------------------
# Product with highest sales in Sweden is MINI HIGHLIGHTER PENS
#  The sales count (in units) is : 5760 and revenue generated is 518.4
# -----------------------------------------------------
# Product with highest sales in Switzerland is GIRLS ALPHABET IRON ON PATCHES
#  The sales count (in units) is : 288 and revenue generated is 60.48
# -----------------------------------------------------
# Product with highest sales in Thailand is ENVELOPE 50 BLOSSOM IMAGES
#  The sales count (in units) is : 288 and revenue generated is 120.96
# -----------------------------------------------------
# Product with highest sales in USA is TOAST ITS - I LOVE YOU
#  The sales count (in units) is : 408 and revenue generated is 452.4
# -----------------------------------------------------
# Product with highest sales in United Arab Emirates is BOYS ALPHABET IRON ON PATCHES
#  The sales count (in units) is : 288 and revenue generated is 60.48
# -----------------------------------------------------
# Product with highest sales in United Kingdom is WHITE HANGING HEART T-LIGHT HOLDER
#  The sales count (in units) is : 52252 and revenue generated is 146226.43
# -----------------------------------------------------
# Product with highest sales in Unspecified is 60 TEATIME FAIRY CAKE CASES
#  The sales count (in units) is : 120 and revenue generated is 66.0
# -----------------------------------------------------
# Product with highest sales in West Indies is BROCADE RING PURSE
#  The sales count (in units) is : 36 and revenue generated is 7.56
# -----------------------------------------------------

# %%
filtered_retaildata.columns
# Out:
# Index(['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'Price', 'Customer ID', 'Country', 'Revenue'],
#       dtype='object')

# %%
revenue_country_wise = filtered_retaildata.groupby('Country').agg({'Revenue':np.sum}).reset_index()

# %%
x1 = revenue_country_wise.sort_values('Revenue' , ascending=False).Country.head(10)
y1 = revenue_country_wise.sort_values('Revenue' , ascending=False).Revenue.head(10)

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.barh(x1,y1)
ax.invert_yaxis()
ax.set_title('Top 10 Countries with maximum revenue')
plt.show()

# %% [markdown]
# #### When were sales highest? On which day?

# %%
filtered_retaildata['InvoiceDateOnly'] = filtered_retaildata.InvoiceDate.apply(lambda x : x.date() )
date_sales = filtered_retaildata.groupby(['InvoiceDateOnly']).agg({'Quantity':np.sum}).reset_index()
date_sales = date_sales.sort_values(['Quantity'],ascending=False)

# %%
date_sales.head()
# Out:
#     InvoiceDateOnly  Quantity
# 243      2010-09-27    125534
# 202      2010-08-09    100236
# 57       2010-02-15     96591
# 83       2010-03-17     78885
# 36       2010-01-21     72914

# %%
print ("Highest sales occurred on {} ({} units).".format(date_sales.head(1).InvoiceDateOnly.values[0],date_sales.head(1).Quantity.values[0]))
# Out:
# Highest sales occurred on 2010-09-27 (125534 units).

# %%
print ("Lowest sales occurred on {} ({} units).".format(date_sales.tail(1).InvoiceDateOnly.values[0],date_sales.tail(1).Quantity.values[0]))
# Out:
# Lowest sales occurred on 2010-02-10 (3783 units).

# %% [markdown]
# #### Sale trends in  5 countries

# %%
country_sales = filtered_retaildata.groupby(['Country']).agg({'Quantity':np.sum}).reset_index()

# %%
country_sales.sort_values(by=['Quantity'], ascending = False).head(5)
# Out:
#            Country  Quantity
# 37  United Kingdom   4720855
# 9          Denmark    229690
# 10            EIRE    193116
# 24     Netherlands    183616
# 12          France    163183

# %%
countries = country_sales.sort_values(by=['Quantity'], ascending = False).head(5).Country.tolist()

# %%
for country in countries:
    country_sales = filtered_retaildata[filtered_retaildata.Country ==country]
    temp = country_sales.groupby(['InvoiceDateOnly']).agg({'Quantity':np.sum}).reset_index().set_index('InvoiceDateOnly')
    temp.plot(title=('Sale trends for '+country))
    plt.show()

# %% [markdown]
# ### Top 5 Most common countries

# %%
#Top 5 Most common countries
filtered_retaildata.Country.value_counts()[:5].plot(kind='bar')

# %% [markdown]
# ### Top 5 least common countries

# %%
filtered_retaildata.Country.value_counts()[-5:].plot(kind='bar')

# %% [markdown]
# ### Total unit price sold by year

# %%
retaildata['Year'] = retaildata['InvoiceDate'].dt.year
retaildata.head()
retaildata.groupby('Year')['Price'].sum().plot(kind='bar')

# %% [markdown]
# ### Total quantity sold by Invoiceno [Top 10]

# %%
retaildata.groupby('Invoice')['Quantity'].sum().sort_values(ascending=False)[:10].plot(kind='bar')

# %% [markdown]
# ### Total quantity sold by Stock Code [Top 10]

# %%
retaildata.groupby('StockCode')['Quantity'].sum().sort_values(ascending=False)[:10].plot(kind='bar')

# %% [markdown]
# #### StockCode

# %%
retaildata.StockCode.nunique()
# Out:
# 4632

# %%
#Finding the Common StockCode
stockcode_counts = retaildata.StockCode.value_counts().sort_values(ascending=False)
fig, ax = plt.subplots(2,1,figsize=(20,15))
sns.barplot(stockcode_counts.iloc[0:20].index,
            stockcode_counts.iloc[0:20].values,
            ax = ax[0], palette="GnBu")
ax[0].set_ylabel("Counts")
ax[0].set_xlabel("Stockcode")
ax[0].set_title(" Stock codes vs Frequency");
sns.distplot(np.round(stockcode_counts/retaildata.shape[0]*100,2),
             kde=False,
             bins=20,
             ax=ax[1], color="Blue")
ax[1].set_title("Stock Code Frequency")
ax[1].set_xlabel("% of data with this stockcode")
ax[1].set_ylabel("Frequency");

# %% [markdown]
# Most stockcodes are very seldom. This indicates that the retailer sells many different products and that there is no strong corelation of a specific stockcode

# %% [markdown]
# ### Descriptions

# %%
#Unique number of Descriptions
retaildata.Description.nunique()
# Out:
# 4681

# %%
#Finding Common Descriptions
description_counts = retaildata.Description.value_counts().sort_values(ascending=False).iloc[0:30]
plt.figure(figsize=(20,5))
sns.barplot(description_counts.index, description_counts.values)
plt.ylabel("Counts")
plt.title("Common Descriptions");
plt.xticks(rotation=90);

# %% [markdown]
# ### Customers

# %%
retaildata['Customer ID'].nunique()
# Out:
# 4383

# %% [markdown]
# Most common Custumers

# %%
customer_counts = retaildata['Customer ID'].value_counts().sort_values(ascending=False).iloc[0:20] 
plt.figure(figsize=(20,5))
sns.barplot(customer_counts.index, customer_counts.values, order=customer_counts.index)
plt.ylabel("Counts")
plt.xlabel("CustomerID")
plt.title(" Most common Custumers");

# %% [markdown]
# #### Transaction with respect to time of the day

# %%
# Writing helper functions to evaluate day, month, year and hour
def getMonth(value):
    return int(value.strftime('%m'))
def getDay(value):
    return int(value.strftime('%d'))
def getYear(value):
    return int(value.strftime('%Y'))
def getHour(value):
    return int(value.strftime('%H'))

# Evaluating the time
month=retaildata['InvoiceDate'].apply(getMonth)
day=retaildata['InvoiceDate'].apply(getDay)
year=retaildata['InvoiceDate'].apply(getYear)
hour=retaildata['InvoiceDate'].apply(getHour)

# %%
#Plot bar chart by Month
sales_plot = month.value_counts().sort_index().plot(kind='bar')
sales_plot.set_xlabel('Months')
sales_plot.set_ylabel('Txn Count')
# Out:
# Text(0, 0.5, 'Txn Count')

# %%
#Plot bar chart by Day
day.value_counts().sort_index().plot(kind='bar')

# %%
# Average Transactions per Week
day_sales = day.value_counts().sort_index()

week_data = ['Week1', 'Week2', 'Week3', 'Week4']
count_data = [day_sales[0:7].mean(),day_sales[7:14].mean(),day_sales[14:21].mean(),day_sales[21:].mean()]
data = {'Week': week_data, 
        'Count': count_data}
week_df = pd.DataFrame(data) 
week_df.reset_index().set_index('Week')

week_plot = week_df.plot(kind= 'bar')
week_plot.set_xlabel('Weeks')
week_plot.set_ylabel('Txn Count')
week_plot.set_title('Avg Txns per Week')
# Out:
# Text(0.5, 1.0, 'Avg Txns per Week')

# %% [markdown]
# First week of every month has good sales count.
# As the graph shows, the number of transactions declines after the 1st week, which signifies decreasing amounts of cash with people towards the end of the month.

# %%
#Plot bar chart by Year
year.value_counts().sort_index().plot(kind='bar')

# %%
#Plot bar chart by Hour
hour.value_counts().sort_index().plot(kind='bar')

# %% [markdown]
# Huge sales are happening around 12 PM everyday

# %% [markdown]
# # RFM Analysis

# %% [markdown]
# #### Recency

# %%
from datetime import datetime,timedelta

# %%
filtered_retaildata.head()
# Out:
#   Invoice StockCode  ... Revenue  InvoiceDateOnly
# 0  489434     85048  ...    83.4       2009-12-01
# 1  489434    79323P  ...    81.0       2009-12-01
# 2  489434    79323W  ...    81.0       2009-12-01
# 3  489434     22041  ...   100.8       2009-12-01
# 4  489434     21232  ...    30.0       2009-12-01
#
# [5 rows x 10 columns]

# %%
orders = filtered_retaildata.groupby(['Invoice', 'InvoiceDate', 'Customer ID']).agg({'Price': lambda x: x.sum()}).reset_index()
orders.head()
# Out:
#   Invoice         InvoiceDate  Customer ID  Price
# 0  489434 2009-12-01 07:45:00      13085.0  32.65
# 1  489435 2009-12-01 07:46:00      13085.0  10.50
# 2  489436 2009-12-01 09:06:00      13078.0  70.88
# 3  489437 2009-12-01 09:08:00      15362.0  83.45
# 4  489438 2009-12-01 09:24:00      18102.0  44.05

# %%
NOW = orders['InvoiceDate'].max() + timedelta(days=1)
NOW
# Out:
# Timestamp('2010-12-10 20:01:00')

# %%
period = 365

# %%
orders['DaysSinceOrder'] = orders['InvoiceDate'].apply(lambda x: (NOW - x).days)

# %%
aggr = {
    'DaysSinceOrder': lambda x: x.min(),  # the number of days since last order (Recency)
    'InvoiceDate': lambda x: len([d for d in x if d >= NOW - timedelta(days=period)]), # the total number of orders in the last period (Frequency)
}
RFM = orders.groupby('Customer ID').agg(aggr).reset_index()
RFM.rename(columns={'DaysSinceOrder': 'Recency', 'InvoiceDate': 'Frequency'}, inplace=True)
RFM.head()
# Out:
#    Customer ID  Recency  Frequency
# 0      12346.0      165         11
# 1      12347.0        3          2
# 2      12348.0       74          1
# 3      12349.0       43          3
# 4      12351.0       11          1

# %%
RFM['Revenue'] = RFM['Customer ID'].apply(lambda x: orders[(orders['Customer ID'] == x) & \
                                                           (orders['InvoiceDate'] >= NOW - timedelta(days=period))]\
                                                           ['Price'].sum())
RFM.head()
# Out:
#    Customer ID  Recency  Frequency  Revenue
# 0      12346.0      165         11   206.36
# 1      12347.0        3          2   162.95
# 2      12348.0       74          1    14.39
# 3      12349.0       43          3   875.34
# 4      12351.0       11          1    49.46

# %%
quantiles = RFM[['Recency', 'Frequency', 'Revenue']].quantile([.2, .4, .6, .8]).to_dict()
quantiles
# Out:
# {'Frequency': {0.2: 1.0, 0.4: 2.0, 0.6: 3.0, 0.8: 6.0},
#  'Recency': {0.2: 15.0, 0.4: 36.0, 0.6: 71.0, 0.8: 176.0},
#  'Revenue': {0.2: 41.842,
#   0.4: 93.994,
#   0.6: 183.26799999999997,
#   0.8: 381.6700000000002}}

# %% [markdown]
# Score:
#
#     1 to the least 20 % percentile
#     2 to the values in 20-40 % percentile
#     3 to the values in 41-60 % percentile
#     4 to the values in 61-80 % percentile
#     5 to the values in 81-100 % percentile

# %%
def recency_score(x):
    if x <= quantiles['Recency'][.2]:
        return 5
    elif x <= quantiles['Recency'][.4]:
        return 4
    elif x <= quantiles['Recency'][.6]:
        return 3
    elif x <= quantiles['Recency'][.8]:
        return 2
    else:
        return 1
    
def freq_mon_score(x, c):
    if x <= quantiles[c][.2]:
        return 1
    elif x <= quantiles[c][.4]:
        return 2
    elif x <= quantiles[c][.6]:
        return 3
    elif x <= quantiles[c][.8]:
        return 4
    else:
        return 5

# %%
RFM['Recency_Score'] = RFM['Recency'].apply(lambda x: recency_score(x))
RFM['Frequency_Score'] = RFM['Frequency'].apply(lambda x: freq_mon_score(x, 'Frequency'))
RFM['Monetary_Score'] = RFM['Revenue'].apply(lambda x: freq_mon_score(x, 'Revenue'))

# %%
RFM['RFM_Score'] = RFM['Recency_Score'].map(str) + RFM['Frequency_Score'].map(str) + RFM['Monetary_Score'].map(str)
RFM.head()
# Out:
#    Customer ID  Recency  Frequency  ...  Frequency_Score  Monetary_Score  RFM_Score
# 0      12346.0      165         11  ...                5               4        254
# 1      12347.0        3          2  ...                2               3        523
# 2      12348.0       74          1  ...                1               1        211
# 3      12349.0       43          3  ...                3               5        335
# 4      12351.0       11          1  ...                1               2        512
#
# [5 rows x 8 columns]

# %% [markdown]
# The segments we figured out from RFM scores after some research:
#
# | Segment                     | Description                                                                                     | Score      |
# |-----------------------------|-------------------------------------------------------------------------------------------------|------------|
# | Loyal Customers             | Bought recently, buy often and spend the most                                                   | [3-4][4-5] |
# | Potential Loyalist          | Recent customers with average frequency                                                         | [4-5][2-3] |
# | New Customers               | Bought most recently, but not often.                                                            | [1-2]5         |
# | Promising                   | Recent shoppers, but haven’t spent much.                                                        | 41         |
# | Needing Attention | Above average recency, frequency and monetary values. May not have bought very recently though. | 33         |
# | At Risk                     | Below average recency and frequency, purchased long ago                                         | [1-2][3-4] |
# | Hibernating                 | Haven't purchased in a long time                                                                | [1-2][1-2] |

# %%
segt_map = {
    r'[4-5][4-5]': 'Loyal Customers',
    r'[4-5][1-3]': 'Potential Loyalist',
    r'[1-2]5': 'New Customers',
    r'[2-4][1-2]': 'Promising',
    r'33': 'Needing Attention',
    r'[1-3][4-5]': 'At Risk',
    r'[1-2][1-3]': 'Hibernating',
}

RFM['RFM_Score'] = RFM['Recency_Score'].map(str) + RFM['Frequency_Score'].map(str)
RFM['Segment'] = RFM['RFM_Score'].replace(segt_map, regex=True)
RFM['RFM_Score'] = RFM['Recency_Score'].map(str) + RFM['Frequency_Score'].map(str)  + RFM['Monetary_Score'].map(str)

RFM.head()
# Out:
#    Customer ID  Recency  ...  RFM_Score             Segment
# 0      12346.0      165  ...        254       New Customers
# 1      12347.0        3  ...        523  Potential Loyalist
# 2      12348.0       74  ...        211           Promising
# 3      12349.0       43  ...        335   Needing Attention
# 4      12351.0       11  ...        512  Potential Loyalist
#
# [5 rows x 9 columns]

# %%
# plot the distribution of customers over R and F
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))

for i, p in enumerate(['Recency_Score', 'Frequency_Score']):
    parameters = {'Recency_Score':'Recency', 'Frequency_Score':'Frequency'}
    y = RFM[p].value_counts().sort_index()
    x = y.index
    ax = axes[i]
    bars = ax.bar(x, y, color='grey')
    ax.set_frame_on(False)
    ax.tick_params(left=False, labelleft=False, bottom=False)
    ax.set_title('Distribution of {}'.format(parameters[p]),
                fontsize=14)
    for bar in bars:
        value = bar.get_height()
        if value == y.max():
            bar.set_color('skyblue')
        ax.text(bar.get_x() + bar.get_width() / 2,
                value - 5,
                '{}\n({}%)'.format(int(value), int(value * 100 / y.sum())),
               ha='center',
               va='top',
               color='w')
        
plt.show()

# plot the distribution of M for RF score
fig, axes = plt.subplots(nrows=5, ncols=5,
                         sharex=False, sharey=True,
                         figsize=(10, 10))

r_range = range(1, 6)
f_range = range(1, 6)
for r in r_range:
    for f in f_range:
        y = RFM[(RFM['Recency_Score'] == r) & (RFM['Frequency_Score'] == f)]['Monetary_Score'].value_counts().sort_index()
        x = y.index
        ax = axes[r - 1, f - 1]
        bars = ax.bar(x, y, color='grey')
        if r == 5:
            if f == 3:
                ax.set_xlabel('{}\nF'.format(f), va='top')
            else:
                ax.set_xlabel('{}\n'.format(f), va='top')
        if f == 1:
            if r == 3:
                ax.set_ylabel('R\n{}'.format(r))
            else:
                ax.set_ylabel(r)
        ax.set_frame_on(False)
        ax.tick_params(left=False, labelleft=False, bottom=False)
        ax.set_xticks(x)
        ax.set_xticklabels(x, fontsize=8)

        for bar in bars:
            value = bar.get_height()
            if value == y.max():
                bar.set_color('skyblue')
            ax.text(bar.get_x() + bar.get_width() / 2,
                    value,
                    int(value),
                    ha='center',
                    va='bottom',
                    color='k')
fig.suptitle('Distribution of Monetary Score for each Frequency and Recency Score',
             fontsize=14)
plt.tight_layout()
plt.show()

# %%
# count the number of customers in each segment
segments_counts = RFM['Segment'].value_counts().sort_values(ascending=True)

fig, ax = plt.subplots()

bars = ax.barh(range(len(segments_counts)),
              segments_counts,
              color='grey')
ax.set_frame_on(False)
ax.tick_params(left=False,
               bottom=False,
               labelbottom=False)
ax.set_yticks(range(len(segments_counts)))
ax.set_yticklabels(segments_counts.index)

for i, bar in enumerate(bars):
        value = bar.get_width()
        if segments_counts.index[i] in ['Potential Loyalist', 'Loyal Customers']:
            bar.set_color('skyblue')
        ax.text(value,
                bar.get_y() + bar.get_height()/2,
                '{:,} ({:}%)'.format(int(value),
                                   int(value*100/segments_counts.sum())),
                va='center',
                ha='left'
               )

plt.show()

# %%
RFM.head()
# Out:
#    Customer ID  Recency  ...  RFM_Score             Segment
# 0      12346.0      165  ...        254       New Customers
# 1      12347.0        3  ...        523  Potential Loyalist
# 2      12348.0       74  ...        211           Promising
# 3      12349.0       43  ...        335   Needing Attention
# 4      12351.0       11  ...        512  Potential Loyalist
#
# [5 rows x 9 columns]

# %%
x2 = RFM.sort_values('Frequency' , ascending=False)['Customer ID'].head(10)
y2 = RFM.sort_values('Frequency' , ascending=False).Frequency.head(10)

# %%
x2 = x2.astype(str)

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.barh(x2,y2)
ax.invert_yaxis()
ax.set_title('Top 10 customers with most frequency of purchases')
plt.show()

# %%
#Count of customers for Recency Score
RFM.Recency_Score.value_counts()
# Out:
# 5    906
# 1    855
# 4    853
# 3    850
# 2    848
# Name: Recency_Score, dtype: int64

# %%
#Count of customers for  Frequency Score
RFM.Frequency_Score.value_counts()
# Out:
# 1    1490
# 2     806
# 4     795
# 5     705
# 3     516
# Name: Frequency_Score, dtype: int64

# %%
#Count of customers for Monetary Score
RFM.Monetary_Score.value_counts()
# Out:
# 5    863
# 1    863
# 3    862
# 2    862
# 4    862
# Name: Monetary_Score, dtype: int64

# %%
RFM.RFM_Score = RFM.RFM_Score.astype(str)

# %%
#Unique RFM Scores that we grouped into Segments
RFM.RFM_Score.unique()
# Out:
# array(['254', '523', '211', '335', '512', '522', '311', '112', '434',
#        '425', '344', '544', '232', '111', '334', '134', '123', '333',
#        '423', '424', '114', '323', '255', '514', '511', '223', '245',
#        '113', '433', '444', '345', '212', '312', '313', '234', '555',
#        '355', '455', '213', '545', '412', '124', '321', '432', '224',
#        '435', '155', '244', '314', '533', '121', '422', '354', '322',
#        '315', '454', '233', '221', '235', '142', '542', '443', '324',
#        '535', '543', '445', '222', '531', '122', '413', '125', '225',
#        '133', '214', '553', '243', '532', '452', '145', '325', '524',
#        '231', '251', '431', '115', '411', '534', '132', '442', '343',
#        '554', '352', '341', '513', '521', '242', '451', '144', '421',
#        '332', '353', '414', '331', '131', '342', '135', '241', '143',
#        '141', '541', '253', '154', '215', '525', '441', '453', '415',
#        '151', '252', '552', '351'], dtype=object)

# %%
# Count of customers for each segment
RFM.Segment.value_counts()
# Out:
# Loyal Customers       1007
# Promising              984
# Hibernating            951
# Potential Loyalist     752
# At Risk                442
# Needing Attention      125
# New Customers           51
# Name: Segment, dtype: int64

# %%
df_with_rfm = filtered_retaildata.merge(RFM)

# %% [markdown]
# #### Most valuable customers:

# %%
print ("The 10 most valuable customers are:")
for i in RFM.sort_values('RFM_Score',ascending=False).head(10)['Customer ID']:
    print (str(int(i)))
# Out:
# The 10 most valuable customers are:
# 14081
# 15580
# 13448
# 17377
# 15716
# 17389
# 17402
# 17412
# 15680
# 13468

# %% [markdown]
# #### Country with most valuable customers:

# %%
most_valuable_country = df_with_rfm.groupby(['Country','RFM_Score']).size().to_frame().reset_index()

# %%
print ("The country which has the most valuable customer is {}.".format(most_valuable_country[most_valuable_country.RFM_Score == np.max(most_valuable_country.RFM_Score)].Country.values[0]))
# Out:
# The country which has the most valuable customer is United Kingdom.

# %% [markdown]
# #### Frequent customers

# %%
print ("The most frequent customer is {}.".format(df_with_rfm[df_with_rfm.Frequency == df_with_rfm.Frequency.max()]['Customer ID'].unique()[0].astype(int)))
# Out:
# The most frequent customer is 17182.

# %%
print ("The least frequent customer is {}.".format(df_with_rfm[df_with_rfm.Frequency == df_with_rfm.Frequency.min()]['Customer ID'].unique()[0].astype(int)))
# Out:
# The least frequent customer is 15823.

# %% [markdown]
# #### Customer spending

# %%
print ("Customer who spent the most: {}.".format(df_with_rfm[df_with_rfm.Revenue == df_with_rfm.Revenue.max()]['Customer ID'].unique()[0].astype(int)))
# Out:
# Customer who spent the most: 12918.

# %%
print ("Customer who spent the least: {}.".format(df_with_rfm[df_with_rfm.Revenue == df_with_rfm.Revenue.min()]['Customer ID'].unique()[0].astype(int)))
# Out:
# Customer who spent the least: 14095.

# %% [markdown]
# ### Clustering
# Now that we did customer segmentation ourselves with RFM scores, we will be implementing clustering to cluster customers in different categories using KMeans Clustering

# %% [markdown]
# The K-means clustering belongs to the partition based\centroid based hard clustering family of algorithms, a family of algorithms where each sample in a dataset is assigned to exactly one cluster.

# %%
# We will be using RFM dataset for clustering
rfm_data = RFM
rfm_data = rfm_data.drop(columns=['Segment'],axis=1)
rfm_data = rfm_data.drop(columns=['Recency_Score','Frequency_Score','Monetary_Score'],axis=1)
rfm_data.head()
# Out:
#    Customer ID  Recency  Frequency  Revenue RFM_Score
# 0      12346.0      165         11   206.36       254
# 1      12347.0        3          2   162.95       523
# 2      12348.0       74          1    14.39       211
# 3      12349.0       43          3   875.34       335
# 4      12351.0       11          1    49.46       512

# %%
#Set index as Customer ID 
rfm_data = rfm_data.set_index('Customer ID')

# %%
#Feature correlations 
rfm_data.corr()
# Out:
#             Recency  Frequency   Revenue
# Recency    1.000000  -0.256469 -0.155989
# Frequency -0.256469   1.000000  0.718496
# Revenue   -0.155989   0.718496  1.000000

# %%
sns.heatmap(rfm_data.corr())

# %% [markdown]
# We can observe that there is negative correlation between:
#     Recency and Frequency
#     Recency and Revenue
#
# Correlation between Revenue ane Frequency is positive (makes sense)

# %%
#Visualizing feature distributions to get a better idea
from pandas.plotting import scatter_matrix
scatter_matrix(rfm_data, alpha = 0.3, figsize = (11,5), diagonal = 'kde');

# %% [markdown]
# There is a skewed distribution in all these 3 features and we can also observe a lot of outliers in this dataset
#
# Due to this, we will need to have the features normally distribute to use clustering algorithms on it

# %%
#Data Normalization (log transformation)


rfm_recency_log = np.log(rfm_data['Recency']+0.1) #can't take log(0) and so add a small number
rfm_frequency_log = np.log(rfm_data['Frequency']+0.1)
rfm_monetary_log = np.log(rfm_data['Revenue']+0.1)

# %%
log_rfm_data = pd.DataFrame({'Monetary': rfm_monetary_log,'Recency': rfm_recency_log,'Frequency': rfm_frequency_log})

# %%
log_rfm_data.describe()
# Out:
#           Monetary      Recency    Frequency
# count  4312.000000  4312.000000  4312.000000
# mean      4.710772     3.802961     0.957131
# std       1.652034     1.378562     0.957315
# min      -2.302585     0.095310    -2.302585
# 25%       3.985181     2.895912     0.095310
# 50%       4.872675     3.972177     0.741937
# 75%       5.738160     4.913390     1.629241
# max      10.336747     5.924523     5.303802

# %%
#Let's produce scatter matrix again to check distribution
scatter_matrix(log_rfm_data, alpha = 0.2, figsize = (11,5), diagonal = 'kde');

# %%
log_rfm_data.corr()
# Out:
#            Monetary   Recency  Frequency
# Monetary   1.000000 -0.448339   0.759175
# Recency   -0.448339  1.000000  -0.559118
# Frequency  0.759175 -0.559118   1.000000

# %% [markdown]
# ### Let's now proceed to apply Kmeans algorithm on this dataset

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
X_scaled = log_rfm_data

# %% [markdown]
# #### Using the Elbow method to get the best K for KMeans with this dataset

# %%
cl = 50
corte = 0.1

anterior = 100000000000000
cost = [] 
K_best = cl

for k in range (1, cl+1):
    # Create a kmeans model on our data, using k clusters.  random_state helps ensure that the algorithm returns the same results each time.
    model = KMeans(
        n_clusters=k, 
        init='k-means++', #'random',
        n_init=10,
        max_iter=300,
        tol=1e-04,
        random_state=101)

    model = model.fit(X_scaled)

    # These are our fitted labels for clusters -- the first cluster has label 0, and the second has label 1.
    labels = model.labels_
 
    # Sum of distances of samples to their closest cluster center
    interia = model.inertia_
    if (K_best == cl) and (((anterior - interia)/anterior) < corte): K_best = k - 1
    cost.append(interia)
    anterior = interia

plt.figure(figsize=(8, 6))
plt.scatter(range (1, cl+1), cost, c='red')
plt.show()

# Create a kmeans model with the best K.
print('The best K: ',K_best)
# Out:
# The best K:  8

# %%
#So we will be using K as 8 for KMeans clustering

#Before applying KMeans, We will also be using PCA to reduce dimensions of our dataset
from sklearn.decomposition import PCA

# %%
# I will be using k = 8
kmeans = KMeans(n_clusters=8,random_state=0)
kmeans.fit(X_scaled)
# kmeans.labels_
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=8, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=0, tol=0.0001, verbose=0)

# %%
clusters = kmeans.predict(log_rfm_data)

# %%
# xx = log_rfm_data.as_matrix()
xx = log_rfm_data.to_numpy()

# %% [markdown]
# #### Visualizing clusters formed using KMeans

# %%
#create a scatter plot
plt.scatter(xx[:, 0], xx[:, 1], c=clusters, s=50, cmap='viridis')
#select cluster centers
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1],marker='*', c='red', s=200)

# %%
# What's the number of customers in each cluster?
pd.DataFrame(pd.Series(clusters).value_counts(), columns = ['Number of Customers']).T
# Out:
#                        6    5    2    1    7    4    3   0
# Number of Customers  879  860  734  632  520  320  294  73

# %% [markdown]
# Unfortunately, we didn't obtain clear and isolated clusters via KMeans. Clusters assignments are muddled. (This may have happened due to outliers).

# %% [markdown]
# ### Clustering using Hierarchical Clustering with dendrograms

# %%
# This clustering will also assume data is scaled and normalised so we will be using log_rfm_data from earlier

# %%
# from scipy.cluster.hierarchy import dendrogram 
from scipy.cluster.hierarchy import dendrogram
from sklearn.cluster import AgglomerativeClustering

def plot_dendrogram(model, **kwargs):
    # Create linkage matrix and then plot the dendrogram

    # create the counts of samples under each node
    counts = np.zeros(model.children_.shape[0])
    n_samples = len(model.labels_)
    for i, merge in enumerate(model.children_):
        current_count = 0
        for child_idx in merge:
            if child_idx < n_samples:
                current_count += 1  # leaf node
            else:
                current_count += counts[child_idx - n_samples]
        counts[i] = current_count

    linkage_matrix = np.column_stack([model.children_, model.distances_,
                                      counts]).astype(float)

    # Plot the corresponding dendrogram
    dend = dendrogram(linkage_matrix, **kwargs)
    return dend


X = np.array(log_rfm_data)

# setting distance_threshold=0 ensures we compute the full tree.
model = AgglomerativeClustering(distance_threshold=0, n_clusters=None)

model = model.fit(X)
plt.figure(figsize=(10,10))
plt.title('Hierarchical Clustering Dendrogram')
# plot the top levels of the dendrogram
dend = plot_dendrogram(model, truncate_mode='level', p=3,leaf_font_size=8, get_leaves=True,orientation='right') #p is the number of levels
plt.xlabel("Number of points in node")
plt.show()

# %%
dend['ivl']
# Out:
# ['(136)',
#  '(370)',
#  '(171)',
#  '(298)',
#  '(31)',
#  '(122)',
#  '(64)',
#  '(226)',
#  '(16)',
#  '(15)',
#  '(17)',
#  '(23)',
#  '(483)',
#  '(938)',
#  '(815)',
#  '(587)']

# %%
dend['leaves']
# Out:
# [8595,
#  8599,
#  8576,
#  8588,
#  8548,
#  8585,
#  8600,
#  8601,
#  4442,
#  4459,
#  4447,
#  4501,
#  8606,
#  8613,
#  8611,
#  8616]

# %%
dend['icoord']
# Out:
# [[5.0, 5.0, 15.0, 15.0],
#  [25.0, 25.0, 35.0, 35.0],
#  [10.0, 10.0, 30.0, 30.0],
#  [45.0, 45.0, 55.0, 55.0],
#  [65.0, 65.0, 75.0, 75.0],
#  [50.0, 50.0, 70.0, 70.0],
#  [20.0, 20.0, 60.0, 60.0],
#  [85.0, 85.0, 95.0, 95.0],
#  [105.0, 105.0, 115.0, 115.0],
#  [90.0, 90.0, 110.0, 110.0],
#  [125.0, 125.0, 135.0, 135.0],
#  [145.0, 145.0, 155.0, 155.0],
#  [130.0, 130.0, 150.0, 150.0],
#  [100.0, 100.0, 140.0, 140.0],
#  [40.0, 40.0, 120.0, 120.0]]

# %%
dend['dcoord']
# Out:
# [[0.0, 17.236300858687986, 17.236300858687986, 0.0],
#  [0.0, 21.704995123170008, 21.704995123170008, 0.0],
#  [17.236300858687986,
#   26.716490706336376,
#   26.716490706336376,
#   21.704995123170008],
#  [0.0, 9.831305861757139, 9.831305861757139, 0.0],
#  [0.0, 16.185769608849764, 16.185769608849764, 0.0],
#  [9.831305861757139,
#   29.989899918269934,
#   29.989899918269934,
#   16.185769608849764],
#  [26.716490706336376, 55.4425622400107, 55.4425622400107, 29.989899918269934],
#  [0.0, 0.02081828911850011, 0.02081828911850011, 0.0],
#  [0.0, 0.029038435176414096, 0.029038435176414096, 0.0],
#  [0.02081828911850011,
#   0.08724594196430463,
#   0.08724594196430463,
#   0.029038435176414096],
#  [0.0, 36.03943470800343, 36.03943470800343, 0.0],
#  [0.0, 50.650393036209614, 50.650393036209614, 0.0],
#  [36.03943470800343, 65.64809664377574, 65.64809664377574, 50.650393036209614],
#  [0.08724594196430463,
#   85.35538295070238,
#   85.35538295070238,
#   65.64809664377574],
#  [55.4425622400107, 134.37689282174134, 134.37689282174134, 85.35538295070238]]

# %%
dend['color_list']
# Out:
# ['g', 'g', 'g', 'g', 'g', 'g', 'g', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'b']

# %% [markdown]
# ### Using Gaussian Mixture Models for clustering
# While K-means was easy to understand and implement. It fails when dealing with non-circular shapes and lack of probabilistic cluster assignment—mean that for many datasets (especially low-dimensional datasets) it may not perform very well.
#
# ##### K-means only considers the mean to update the centroid while GMM takes into account the mean as well as the variance of the data!

# %% [markdown]
# Gaussian Mixture Models are probabilistic models and use the soft clustering approach for distributing the points in different clusters.
# Gaussian Mixture Models (GMMs) assume that there are a certain number of Gaussian distributions, and each of these distributions represent a cluster. Hence, a Gaussian Mixture Model tends to group the data points belonging to a single distribution together.

# %%
from sklearn.mixture import GaussianMixture as GMM
# log_matrix = log_rfm_data.as_matrix()
log_matrix = log_rfm_data.to_numpy()
gmm = GMM(n_components=8,init_params='random').fit(log_matrix)
labels = gmm.predict(log_matrix)
plt.scatter(log_matrix[:, 1], log_matrix[:, 2], c=labels, s=40, cmap='viridis');

# %%
gmm.covariances_
# Out:
# array([[[ 9.87669175e-01, -4.60382427e-02,  4.41906380e-31],
#         [-4.60382427e-02,  1.35493158e+00,  2.16304120e-31],
#         [ 4.41906380e-31,  2.16304120e-31,  1.00000000e-06]],
#
#        [[ 2.42661386e+00,  3.64794528e-02,  1.62715233e-01],
#         [ 3.64794528e-02,  8.01184407e-01, -5.91149228e-04],
#         [ 1.62715233e-01, -5.91149228e-04,  5.32814927e-02]],
#
#        [[ 1.00000000e-06,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  6.64759555e-05,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  1.00000000e-06]],
#
#        [[ 7.49309033e-01, -8.90076501e-02,  1.14454782e-30],
#         [-8.90076501e-02,  1.45077496e+00,  8.43881460e-31],
#         [ 1.14915500e-30,  8.36970693e-31,  1.00000000e-06]],
#
#        [[ 1.87042318e+00, -3.94503499e-01,  8.25713417e-01],
#         [-3.94503499e-01,  1.62851549e+00, -1.86496747e-01],
#         [ 8.25713417e-01, -1.86496747e-01,  6.12197004e-01]],
#
#        [[ 4.35389529e-01, -3.90398864e-02,  1.34738629e-01],
#         [-3.90398864e-02,  1.46804666e+00, -2.79207555e-02],
#         [ 1.34738629e-01, -2.79207555e-02,  1.44562218e-01]],
#
#        [[ 4.77041115e-01, -1.13888317e-01,  1.55993852e-02],
#         [-1.13888317e-01,  8.64002467e-01, -6.55488955e-03],
#         [ 1.55993852e-02, -6.55488955e-03,  8.95319965e-03]],
#
#        [[ 1.40090468e+00, -1.11112883e-01,  8.99473523e-33],
#         [-1.11112883e-01,  1.15563182e+00,  2.58940664e-32],
#         [ 9.20320808e-33,  2.57724572e-32,  1.00000000e-06]]])

# %%
labels
# Out:
# array([5, 0, 7, ..., 7, 0, 6])

# %%
# What's the number of customers in each cluster?
pd.DataFrame(pd.Series(labels).value_counts(), columns = ['Number of Customers']).T
# Out:
#                         7    0    5    3    6    4    1   2
# Number of Customers  1419  806  789  514  457  134  122  71
